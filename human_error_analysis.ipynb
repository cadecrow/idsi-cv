# %%
from preprocessing import load_file as l_f
import numpy as np
from PIL import Image
from preprocessing import crop_image as c_i
from os import listdir

# %%
np.random.seed(1)
data_file_name = "sampled_data.csv"
path_training = "train/images/" # path from current folder to training images

### Collect total number of training examples
m = l_f.check_num_images(data_file_name)
m_training = 100

### Shuffle the m examples
list_of_rows = np.arange(1, m+1, 1)
np.random.shuffle(list_of_rows)
### Take a random m_training examples and load the data
img_dict = l_f.load_file(data_file_name, list_of_rows[:m_training])

# %%
### Helper functions ####################
def test_human(path, img_dict):
    no_damage = [0,0]
    major_damage = [0,0]
    accuracy = (no_damage, major_damage)
    ### Loops through image dictionary, opens the image file and processes it
    for fname in img_dict:
        img = Image.open(path + fname)
        ### For each image, go through the specific buildings asked for
        for uid in img_dict[fname]:
            ### Collect the polygon
            xy = img_dict[fname][uid][1]
            ### Crop the image, reshape, and append
            img_crop = c_i.crop_image(img, xy)
            img_rgb = img_crop.convert('RGB')
            img_rgb.show()
            print("no_damage - minor_damage   = 0")
            print("major_damage - destroyed   = 1")
            human_guess = int(input("Enter damage rating: "))
            ### Take the Y value (already converted to number encoding: 0, 1)
            Y = int(img_dict[fname][uid][0])
            accuracy = compare_results(human_guess, Y, accuracy)
    return accuracy

def compare_results(human_guess, Y, accuracy):
    if (human_guess == Y):
        accuracy[Y][0] += 1
    else:
        accuracy[Y][1] += 1
        print("You guessed " + str(human_guess) + " but the correct answer was " + str(Y))
    return accuracy

# %%
accuracy = test_human(path_training, img_dict)
# Out:
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# You guessed 0 but the correct answer was 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# You guessed 1 but the correct answer was 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 0
# no_damage - minor_damage   = 0
# major_damage - destroyed   = 1
# Enter damage rating: 1

# %%
if (accuracy[0][0] + accuracy[0][1]) != 0:
    print("no_damage - minor_damage  = " + str(round(accuracy[0][0]/(accuracy[0][0] + accuracy[0][1]), 2)) + "%")
    print(accuracy[0])
if (accuracy[1][0] + accuracy[1][1]) != 0:
    print("major_damage - destroyed = " + str(round(accuracy[1][0]/(accuracy[1][0] + accuracy[1][1]), 2)) + "%")
    print(accuracy[1])
# Out:
# no_damage - minor_damage  = 0.66%
# [33, 17]
# major_damage - destroyed = 0.82%
# [41, 9]
